# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
r = requests.get(url)
data = r.json()
data = data['Data']
crypto_df = pd.DataFrame.from_dict(data)
crypto_df = crypto_df.T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42         42             0            0           0   blockchain
# 300       300             0            0           0        token
# 365        -1             0            0           0   blockchain
# 404        -1             0            0           0   blockchain
# 433       NaN           NaN          NaN         NaN          NaN
#
#     AlgorithmType Difficulty BuiltOn  \
# 42         scrypt   0.000244     NaN
# 300           NaN        NaN     ETH
# 365           NaN        NaN     NaN
# 404           NaN        NaN     NaN
# 433           NaN        NaN     NaN
#
#                            SmartContractAddress DecimalPoints
# 42                                          NaN           NaN
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557            18
# 365                                         NaN           NaN
# 404                                         NaN           NaN
# 433                                         NaN           NaN
#
# [5 rows x 36 columns]

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# Create a DataFramefrom pathlib import Path
file_path = Path("Resources/crypto_data.csv")
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/111050172.py in <module>
#       3
#       4 # Create a DataFramefrom pathlib import Path
# ----> 5 file_path = Path("Resources/crypto_data.csv")
#       6 crypto_df = pd.read_csv(file_path, index_col=0)
#       7 crypto_df
#
# NameError: name 'Path' is not defined

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df['IsTrading'] == True]

# %%
crypto_df
# Out:
#             Id                     Url                           ImageUrl  \
# 42        4321      /coins/42/overview             /media/35650717/42.jpg
# 300     749869     /coins/300/overview            /media/27010595/300.png
# 365      33639     /coins/365/overview              /media/352070/365.png
# 404      21227     /coins/404/overview    /media/35650851/404-300x300.jpg
# 611      20909     /coins/611/overview  /media/35650940/611-sixeleven.png
# ...        ...                     ...                                ...
# MULTI   947685   /coins/multi/overview          /media/39838579/multi.png
# ANY     936227     /coins/any/overview            /media/37305349/any.png
# BANANA  943188  /coins/banana/overview         /media/38553358/banana.png
# GAMEFI  947696  /coins/gamefi/overview         /media/39838585/gamefi.png
# ACET    947700    /coins/acet/overview           /media/39838587/acet.png
#
#        ContentCreatedOn    Name  Symbol      CoinName               FullName  \
# 42           1427211129      42      42       42 Coin           42 Coin (42)
# 300          1517935016     300     300     300 token        300 token (300)
# 365          1480032918     365     365       365Coin          365Coin (365)
# 404          1466100361     404     404       404Coin          404Coin (404)
# 611          1465914773     611     611     SixEleven        SixEleven (611)
# ...                 ...     ...     ...           ...                    ...
# MULTI        1649172848   MULTI   MULTI    Multichain     Multichain (MULTI)
# ANY          1598442863     ANY     ANY       Anyswap          Anyswap (ANY)
# BANANA       1629990923  BANANA  BANANA       ApeSwap       ApeSwap (BANANA)
# GAMEFI       1649239487  GAMEFI  GAMEFI  GameFi Token  GameFi Token (GAMEFI)
# ACET         1649240838    ACET    ACET          Acet            Acet (ACET)
#
#                                               Description AssetTokenStatus  \
# 42      Everything about 42 coin is 42 - apart from th...              N/A
# 300     300 token is an ERC20 token. This Token was cr...              N/A
# 365     365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404     404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 611     611 is a Namecoin based cryptocurrency, and it...              N/A
# ...                                                   ...              ...
# MULTI   Multichain is a Router for web3. It is an infr...              N/A
# ANY     Anyswap is a fully decentralized cross-chain s...              N/A
# BANANA  ApeSwap is a Decentralized Autonomous Organiza...              N/A
# GAMEFI  GFI is the driving force of GameFi Protocol ec...              N/A
# ACET    ACT (Acet) is a cryptocurrency designed to tac...              N/A
#
#         ...  MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42      ...         42             0            0           0   blockchain
# 300     ...        300             0            0           0        token
# 365     ...         -1             0            0           0   blockchain
# 404     ...         -1             0            0           0   blockchain
# 611     ...          0             0            0           0          NaN
# ...     ...        ...           ...          ...         ...          ...
# MULTI   ...         -1             0            0           0        token
# ANY     ...  100000000         99.99            1           0        token
# BANANA  ...         -1             0            0           0        token
# GAMEFI  ...         -1             0            0           0        token
# ACET    ...         -1             0            0           0        token
#
#        AlgorithmType Difficulty                 BuiltOn  \
# 42            scrypt   0.000244                     NaN
# 300              NaN        NaN                     ETH
# 365              NaN        NaN                     NaN
# 404              NaN        NaN                     NaN
# 611              NaN        NaN                     NaN
# ...              ...        ...                     ...
# MULTI            NaN        NaN  ETH,BNB,MATIC,AVAX,FTM
# ANY              NaN        NaN                     NaN
# BANANA           NaN        NaN                     BNB
# GAMEFI           NaN        NaN                     BNB
# ACET             NaN        NaN                     BNB
#
#                               SmartContractAddress DecimalPoints
# 42                                             NaN           NaN
# 300     0xaec98a708810414878c3bcdf46aad31ded4a4557            18
# 365                                            NaN           NaN
# 404                                            NaN           NaN
# 611                                            NaN           NaN
# ...                                            ...           ...
# MULTI   0x65Ef703f5594D2573eb71Aaf55BC0CB548492df4            18
# ANY                                            NaN           NaN
# BANANA  0x603c7f932ED1fc6575303D8Fb018fDCBb0f39a95            18
# GAMEFI  0xDD6C6C114Db071EFE0BAB6051268227CE64C3fFe            18
# ACET    0x9F3BCBE48E8b754F331Dfc694A894e8E686aC31D            18
#
# [6591 rows x 36 columns]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]

# %%
crypto_df
# Out:
#                Id                        Url  \
# 42           4321         /coins/42/overview
# 365         33639        /coins/365/overview
# 404         21227        /coins/404/overview
# 611         20909        /coins/611/overview
# 808         28223        /coins/808/overview
# ...           ...                        ...
# CRAFTCOIN   29711  /coins/craftcoin/overview
# DESTINY     22330    /coins/destiny/overview
# GLOWSHA      5397    /coins/glowsha/overview
# GHOSTCOIN    5336  /coins/ghostcoin/overview
# BANANA     943188     /coins/banana/overview
#
#                                     ImageUrl ContentCreatedOn       Name  \
# 42                    /media/35650717/42.jpg       1427211129         42
# 365                    /media/352070/365.png       1480032918        365
# 404          /media/35650851/404-300x300.jpg       1466100361        404
# 611        /media/35650940/611-sixeleven.png       1465914773        611
# 808                    /media/351513/808.png       1473980395        808
# ...                                      ...              ...        ...
# CRAFTCOIN            /media/351681/craft.png       1475818685  CRAFTCOIN
# DESTINY                /media/351087/des.png       1467197507    DESTINY
# GLOWSHA             /media/20314/gsxjpeg.png       1430211025    GLOWSHA
# GHOSTCOIN               /media/19721/ghc.png       1430210187  GHOSTCOIN
# BANANA            /media/38553358/banana.png       1629990923     BANANA
#
#               Symbol    CoinName               FullName  \
# 42                42     42 Coin           42 Coin (42)
# 365              365     365Coin          365Coin (365)
# 404              404     404Coin          404Coin (404)
# 611              611   SixEleven        SixEleven (611)
# 808              808         808              808 (808)
# ...              ...         ...                    ...
# CRAFTCOIN  CRAFTCOIN   Craftcoin  Craftcoin (CRAFTCOIN)
# DESTINY      DESTINY     Destiny      Destiny (DESTINY)
# GLOWSHA      GLOWSHA  GlowShares   GlowShares (GLOWSHA)
# GHOSTCOIN  GHOSTCOIN   GhostCoin  GhostCoin (GHOSTCOIN)
# BANANA        BANANA     ApeSwap       ApeSwap (BANANA)
#
#                                                  Description AssetTokenStatus  \
# 42         Everything about 42 coin is 42 - apart from th...              N/A
# 365        365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404        404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 611        611 is a Namecoin based cryptocurrency, and it...              N/A
# 808        808 is a coin develop for the music community ...              N/A
# ...                                                      ...              ...
# CRAFTCOIN  CraftCoin is a cryptocurrency based on Litecoi...              N/A
# DESTINY    Destiny is a Scrypt based cryptocurrency that ...              N/A
# GLOWSHA    Anonymous, decentralized voting on the blockch...              N/A
# GHOSTCOIN  GhostCoin is a Scrypt Altcoin based on both Pr...              N/A
# BANANA     ApeSwap is a Decentralized Autonomous Organiza...              N/A
#
#            ... MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42         ...        42             0            0           0   blockchain
# 365        ...        -1             0            0           0   blockchain
# 404        ...        -1             0            0           0   blockchain
# 611        ...         0             0            0           0          NaN
# 808        ...         0             0            0           0          NaN
# ...        ...       ...           ...          ...         ...          ...
# CRAFTCOIN  ...       NaN           NaN          NaN         NaN          NaN
# DESTINY    ...       NaN           NaN          NaN         NaN          NaN
# GLOWSHA    ...       NaN           NaN          NaN         NaN          NaN
# GHOSTCOIN  ...       NaN           NaN          NaN         NaN          NaN
# BANANA     ...        -1             0            0           0        token
#
#           AlgorithmType Difficulty BuiltOn  \
# 42               scrypt   0.000244     NaN
# 365                 NaN        NaN     NaN
# 404                 NaN        NaN     NaN
# 611                 NaN        NaN     NaN
# 808                 NaN        NaN     NaN
# ...                 ...        ...     ...
# CRAFTCOIN           NaN        NaN     NaN
# DESTINY             NaN        NaN     NaN
# GLOWSHA             NaN        NaN     NaN
# GHOSTCOIN           NaN        NaN     NaN
# BANANA              NaN        NaN     BNB
#
#                                  SmartContractAddress DecimalPoints
# 42                                                NaN           NaN
# 365                                               NaN           NaN
# 404                                               NaN           NaN
# 611                                               NaN           NaN
# 808                                               NaN           NaN
# ...                                               ...           ...
# CRAFTCOIN                                         NaN           NaN
# DESTINY                                           NaN           NaN
# GLOWSHA                                           NaN           NaN
# GHOSTCOIN                                         NaN           NaN
# BANANA     0x603c7f932ED1fc6575303D8Fb018fDCBb0f39a95            18
#
# [1649 rows x 36 columns]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns='IsTrading')

# %%
crypto_df
# Out:
#                Id                        Url  \
# 42           4321         /coins/42/overview
# 365         33639        /coins/365/overview
# 404         21227        /coins/404/overview
# 611         20909        /coins/611/overview
# 808         28223        /coins/808/overview
# ...           ...                        ...
# CRAFTCOIN   29711  /coins/craftcoin/overview
# DESTINY     22330    /coins/destiny/overview
# GLOWSHA      5397    /coins/glowsha/overview
# GHOSTCOIN    5336  /coins/ghostcoin/overview
# BANANA     943188     /coins/banana/overview
#
#                                     ImageUrl ContentCreatedOn       Name  \
# 42                    /media/35650717/42.jpg       1427211129         42
# 365                    /media/352070/365.png       1480032918        365
# 404          /media/35650851/404-300x300.jpg       1466100361        404
# 611        /media/35650940/611-sixeleven.png       1465914773        611
# 808                    /media/351513/808.png       1473980395        808
# ...                                      ...              ...        ...
# CRAFTCOIN            /media/351681/craft.png       1475818685  CRAFTCOIN
# DESTINY                /media/351087/des.png       1467197507    DESTINY
# GLOWSHA             /media/20314/gsxjpeg.png       1430211025    GLOWSHA
# GHOSTCOIN               /media/19721/ghc.png       1430210187  GHOSTCOIN
# BANANA            /media/38553358/banana.png       1629990923     BANANA
#
#               Symbol    CoinName               FullName  \
# 42                42     42 Coin           42 Coin (42)
# 365              365     365Coin          365Coin (365)
# 404              404     404Coin          404Coin (404)
# 611              611   SixEleven        SixEleven (611)
# 808              808         808              808 (808)
# ...              ...         ...                    ...
# CRAFTCOIN  CRAFTCOIN   Craftcoin  Craftcoin (CRAFTCOIN)
# DESTINY      DESTINY     Destiny      Destiny (DESTINY)
# GLOWSHA      GLOWSHA  GlowShares   GlowShares (GLOWSHA)
# GHOSTCOIN  GHOSTCOIN   GhostCoin  GhostCoin (GHOSTCOIN)
# BANANA        BANANA     ApeSwap       ApeSwap (BANANA)
#
#                                                  Description AssetTokenStatus  \
# 42         Everything about 42 coin is 42 - apart from th...              N/A
# 365        365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404        404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 611        611 is a Namecoin based cryptocurrency, and it...              N/A
# 808        808 is a coin develop for the music community ...              N/A
# ...                                                      ...              ...
# CRAFTCOIN  CraftCoin is a cryptocurrency based on Litecoi...              N/A
# DESTINY    Destiny is a Scrypt based cryptocurrency that ...              N/A
# GLOWSHA    Anonymous, decentralized voting on the blockch...              N/A
# GHOSTCOIN  GhostCoin is a Scrypt Altcoin based on both Pr...              N/A
# BANANA     ApeSwap is a Decentralized Autonomous Organiza...              N/A
#
#            ... MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42         ...        42             0            0           0   blockchain
# 365        ...        -1             0            0           0   blockchain
# 404        ...        -1             0            0           0   blockchain
# 611        ...         0             0            0           0          NaN
# 808        ...         0             0            0           0          NaN
# ...        ...       ...           ...          ...         ...          ...
# CRAFTCOIN  ...       NaN           NaN          NaN         NaN          NaN
# DESTINY    ...       NaN           NaN          NaN         NaN          NaN
# GLOWSHA    ...       NaN           NaN          NaN         NaN          NaN
# GHOSTCOIN  ...       NaN           NaN          NaN         NaN          NaN
# BANANA     ...        -1             0            0           0        token
#
#           AlgorithmType Difficulty BuiltOn  \
# 42               scrypt   0.000244     NaN
# 365                 NaN        NaN     NaN
# 404                 NaN        NaN     NaN
# 611                 NaN        NaN     NaN
# 808                 NaN        NaN     NaN
# ...                 ...        ...     ...
# CRAFTCOIN           NaN        NaN     NaN
# DESTINY             NaN        NaN     NaN
# GLOWSHA             NaN        NaN     NaN
# GHOSTCOIN           NaN        NaN     NaN
# BANANA              NaN        NaN     BNB
#
#                                  SmartContractAddress DecimalPoints
# 42                                                NaN           NaN
# 365                                               NaN           NaN
# 404                                               NaN           NaN
# 611                                               NaN           NaN
# 808                                               NaN           NaN
# ...                                               ...           ...
# CRAFTCOIN                                         NaN           NaN
# DESTINY                                           NaN           NaN
# GLOWSHA                                           NaN           NaN
# GHOSTCOIN                                         NaN           NaN
# BANANA     0x603c7f932ED1fc6575303D8Fb018fDCBb0f39a95            18
#
# [1649 rows x 35 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df["TotalCoinsMined"]> 0]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df!='N/A']

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coinname_df = pd.DataFrame(data = crypto_df, columns = ['CoinName'])

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns = 'CoinName')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/1118399956.py in <module>
#       1 # Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
# ----> 2 crypto_df = crypto_df.drop(columns = 'CoinName')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['CoinName'] not found in axis"

# %%
# Create dummy variables for text features
crypto_dummies= pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])

# %%
# Standardize data
crypto_scaled = StandardScaler().fit_transform(crypto_dummies)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/2627101075.py in <module>
#       1 # Standardize data
# ----> 2 crypto_scaled = StandardScaler().fit_transform(crypto_dummies)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     724         n_samples = _num_samples(array)
#     725         if n_samples < ensure_min_samples:
# --> 726             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     727                              " minimum of %d is required%s."
#     728                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 32)) while a minimum of 1 is required by StandardScaler.

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca_df = pd.DataFrame(data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/2842664214.py in <module>
#       1 # Use PCA to reduce dimensions to 3 principal components
# ----> 2 pca_df = pd.DataFrame(data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"])
#
# NameError: name 'crypto_pca' is not defined

# %%
# Create a DataFrame with the principal components data
pca_df = pd.DataFrame(data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_df.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/1730654422.py in <module>
#       1 # Create a DataFrame with the principal components data
# ----> 2 pca_df = pd.DataFrame(data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_df.index)
#
# NameError: name 'crypto_pca' is not defined

# %%
pca_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21428/2753937323.py in <module>
# ----> 1 pca_df
#
# NameError: name 'pca_df' is not defined

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_pca)
    inertia.append(km.inertia_)
# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
km = KMeans(n_clusters=4, random_state=0)
# Fit the model
km.fit(pca_df)
# Predict clusters
predictions = km.predict(pca_df)
# Creating a new DataFrame including predicted clusters and cryptocurrencies features
pca_df['class'] = km.labels_
pca_df.index = crypto_df.index

# %%
clustered_df = pd.concat([crypto_df, pca_df,coins_name], axis=1,)

# %%
clustered_df

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
MM_SCALER = MinMaxScaler()
plot_data =MM_SCALER.fit_transform(clustered_df[["MaxSupply", "TotalCoinsMined"]])
plot_df = pd.DataFrame(plot_data, columns=["MaxSupply", "TotalCoinsMined"], index=clustered_df.index)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
plot_df

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
clustered_df[["CoinName","Algorithm","ProofType","MaxSupply","TotalCoinsMined","Class",]].hvplot.table()

# %%
# Print the total number of tradable cryptocurrencies
print(f"There are {clustered_df.shape()} tradable cryptocurrencies."
